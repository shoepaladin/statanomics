# %% [markdown]
# # Heterogenous treatment effect models
# Julian Hsu
# 30 Aug 2021
#
# ### Table of Contents with Navigation Links
# * [Write ML Models](#Section1)
# * [Simulator Functions](#Section2)
# * [Many Simulations](#Section3)

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

import numpy as np
import os as os 
import scipy.stats 

from matplotlib import gridspec
import matplotlib.pyplot as plt
# %matplotlib inline  

import statsmodels.api as sm
from IPython.display import display    

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, LinearRegression, Lasso, LassoCV, Ridge
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.neural_network import MLPRegressor, MLPClassifier
from sklearn.metrics import mean_squared_error

import warnings

# %%
print(os.getcwd())
import stnomics as st
# Out:
# /Users/hsujulia/Documents/GitHub/statanomics/causalmodels

# %%
def gen_data_hte(N, hte_type):
    '''
    Generate data with different types of HTE forms:
    '''
    
    df = pd.DataFrame()
    x = np.random.uniform(0,1, N)
    y = 10 + 2*(np.log(1+x)) + x**2 + np.random.normal(0,1,N)
    
    if hte_type=='constant':
        hte = 1
    elif hte_type=='linear':
        hte = 2*x
    elif hte_type=='quadratic':
        hte = 0.5*x**2
    elif hte_type=='piecewise':
        hte = np.zeros_like(x)
        hte[(x < 0.20)] = 1
        hte[(x >=0.20) & (x < 0.80) ] = 2
        hte[(x >=0.80) ] = 5
    elif hte_type=='log':
        hte = np.log(1+x*2)*1.5
    elif hte_type=='piecewise_linear':
        hte = np.zeros_like(x)
        hte[(x < 0.20)] = x[(x < 0.20)]*0.1
        hte[(x >=0.20) & (x < 0.80) ] = x[(x >=0.20) & (x < 0.80) ]*0.75
        hte[(x >=0.80) ] = x[(x >=0.80) ]*(-0.5)
    elif hte_type=='trig':
        hte = np.sin(1+x*10)*x
    else:
        print('Choose a hte type!')
        
    t = ( np.exp(x) / (1+np.exp(x)) > np.random.uniform(0,1,N)).astype(float)
    y  += t*hte
    return pd.DataFrame(data={'x':x, 't':t, 'y':y, 'hte': hte})

# %%
model_max_iter = 5000
## treatment prediction models
t_models = {}
t_models['LogitCV'] = LogisticRegressionCV(cv=5, random_state=27, n_jobs=-1)
t_models['logit'] = LogisticRegression(penalty='l2',solver='lbfgs', C=1, max_iter=model_max_iter, fit_intercept=True)
t_models['logit_L1_C2'] = LogisticRegression(penalty='l1',C=2, max_iter=model_max_iter, fit_intercept=True)
t_models['logit_L2_C5'] = LogisticRegression(penalty='l2',C=2, max_iter=model_max_iter, fit_intercept=True)
t_models['rf_md10'] = RandomForestClassifier(n_estimators=25,max_depth=10, min_samples_split=200,n_jobs=-1)
t_models['rf_md3'] = RandomForestClassifier(n_estimators=25,max_depth=3, min_samples_split=200,n_jobs=-1)
t_models['nn'] = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(3, 2), random_state=1,max_iter=model_max_iter)
## outcome prediction models
y_models = {}
y_models['LassoCV'] = LassoCV(cv=5, n_jobs=-1, normalize=True, random_state=27)
y_models['ols'] = LinearRegression()
y_models['lasso_a2'] = Lasso(alpha=2,max_iter=model_max_iter)
y_models['ridge_a2'] = Ridge(alpha=2,max_iter=model_max_iter)
y_models['rf_md10'] = RandomForestRegressor(n_estimators=25,max_depth=10, min_samples_split=200,n_jobs=-1)
y_models['rf_md3'] = RandomForestRegressor(n_estimators=25,max_depth=3, min_samples_split=200,n_jobs=-1)
y_models['nn'] = MLPRegressor(alpha=1e-5, hidden_layer_sizes=(3, 2), random_state=1, max_iter=model_max_iter)

# %%
aux_dictionary = {'force_second_stage':'CVLasso'}
n_data_splits = 5
lasso_max_iter = 5000
lasso_alpha = 5

# from sklearn.utils.testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# %%
N = 5000
i = 0
for t in ['constant','linear','quadratic','piecewise','piecewise_linear']:

    df = gen_data_hte(N, t)
    
    df['x2'] = df['x'].pow(2)
    df['x2_ln'] = np.log(1+df['x'])    
#     for p in range(9):
#         df['x_'+str(p)] = ( np.round(df['x'],1)==np.round(p*0.1,1) ).astype(float)
#         df['x_X'+str(p)] = df['x_'+str(p)]*df['x']
    full_feature_list = [ x for x in df.columns if 'x' in x]

    ## 3. Run through each combination of models
    SGCT = st.hte.het_dml_approaches.SGCT(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, aux_dictionary)
    df['dml_SGCT_TE'] = SGCT[0]
    df['dml_SGCT_SE'] = SGCT[1]    
    df['dml_SGCT_P'] = SGCT[2]
    df['dml_SGCT_Y0'] = SGCT[3]        

    HR = st.hte.het_dml_approaches.HR(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, aux_dictionary)
    df['dml_HR_TE'] = HR[0]
    df['dml_HR_SE'] = HR[1]    
    df['dml_HR_P'] = HR[2]
    df['dml_HR_Y0'] = HR[3]

    dr_cvl = st.hte.other.DR(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, {'force_second_stage':'CVLasso'})
    df['DR_CVL_TE'] = dr_cvl[0]
    df['DR_CVL_SE'] = dr_cvl[1]   
    df['DR_CVL_P'] = dr_cvl[2]
    df['DR_CVL_Y0'] = dr_cvl[3]


    tree_grf = st.hte.trees.grf(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, {'n_estimators':1000})
    df['GRF_TE'] = tree_grf[0]
    df['GRF_SE'] = tree_grf[1]
    df['GRF_P'] = tree_grf[2]
    df['GRF_Y0'] = tree_grf[3]

    fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(20,10),sharex=True, sharey=True)

    ax[0].scatter(df['x'], df['dml_SGCT_TE'], label='SGCT', alpha = 0.15, color='green')
    ax[0].scatter(df['x'], df['dml_HR_TE'], label='HR', alpha = 0.15, color='coral')
    ax[0].scatter(df['x'], df['hte'], label='Truth', alpha = 0.25, color='royalblue')

    ax[0].legend(loc='upper left', fontsize=15)
    ax[0].grid()
    ax[0].set_ylabel('HTE', fontsize=15)
    ax[0].set_xlabel('x', fontsize=15)
    
    ax[1].scatter(df['x'], df['DR_CVL_TE'], label='DoublyRobust', alpha = 0.15, color='purple')
    ax[1].scatter(df['x'], df['GRF_TE'], label='GRF', alpha = 0.15, color='pink')
    ax[1].scatter(df['x'], df['hte'], label='Truth', alpha = 0.25, color='royalblue')
    
    ax[1].legend(loc='upper left', fontsize=15)
    ax[1].grid()
    ax[1].set_ylabel('HTE', fontsize=15)
    ax[1].set_xlabel('x', fontsize=15)
    fig.subplots_adjust(wspace=0.05, hspace=0)
    fig.suptitle('Performance when Functional Form is {0}'.format(i), fontsize=15) 
    fig.patch.set_facecolor('white')
    fig.show()
    i+=1
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.901467085891454, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.305124216153672, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.885567675883067, tolerance: 0.877639761831045
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.85999335446104, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.9227243147634, tolerance: 0.877639761831045
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.204825284103208, tolerance: 0.877639761831045
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.621005008587417, tolerance: 0.877639761831045
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.465159163860335, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.0282742651043, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.464741027000855, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.069812338982047, tolerance: 0.877639761831045
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.310818755107903, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116.83735950596565, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 287.0189404056837, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 476.43250376413107, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 666.2254106078481, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 848.1001354706241, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1018.7005405041209, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1177.036725757308, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1323.2489912816072, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 847.9701621946688, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1064.780815416544, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1261.537373722047, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1438.9941132300123, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1598.836587594752, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.929009237424907, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1742.977150963472, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140.8605505312762, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1873.266381248286, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 356.24411833828617, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1991.3852188675914, tolerance: 0.8614255258006661
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 585.2888080210969, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 804.7223046287663, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1006.9211259998483, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1190.3214539291512, tolerance: 0.8087134560719147
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.837006003039278, tolerance: 0.8660710186181488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.439325391758757, tolerance: 0.8660710186181488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.061876776493591, tolerance: 0.8612443230842973
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.318880466260453, tolerance: 0.8660710186181488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.354588270008207, tolerance: 0.8660710186181488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.223036243249226, tolerance: 0.8612443230842973
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.671348134076652, tolerance: 0.8612443230842973
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.768663389280846, tolerance: 0.8307633221370816
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.436381363338114, tolerance: 0.8660710186181488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.291756594178878, tolerance: 0.8612443230842973
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.225154811234461, tolerance: 0.8307633221370816
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.97912903206543, tolerance: 0.8612443230842973
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.898449034108125, tolerance: 0.8307633221370816
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.637311672761825, tolerance: 0.8612443230842973
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.178287176736376, tolerance: 0.8612443230842973
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.46409769076217, tolerance: 0.8660710186181488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.52142145470225, tolerance: 0.8612443230842973
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57.59278917980646, tolerance: 0.8612443230842973
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.346498095032985, tolerance: 0.8660710186181488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51.000394849348595, tolerance: 0.8660710186181488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.644087304796813, tolerance: 0.8307633221370816
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161.8147067566215, tolerance: 0.8307633221370816
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 384.90989999610883, tolerance: 0.8307633221370816
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 618.6719774937737, tolerance: 0.8307633221370816
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 841.4621405756989, tolerance: 0.8307633221370816
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1046.3136598408882, tolerance: 0.8307633221370816
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.1953614108770125, tolerance: 0.8725670732794357
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.319046696520672, tolerance: 0.8725670732794357
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.651014522907644, tolerance: 0.8725670732794357
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.077217207501235, tolerance: 0.8725670732794357
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.493797380773685, tolerance: 0.8725670732794357
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.80609977385029, tolerance: 0.8725670732794357
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44.9277892913924, tolerance: 0.8725670732794357
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.627e+02, tolerance: 1.079e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.627e+02, tolerance: 1.079e+00
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-6-fb50426e5489>:78: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1874852385517443, tolerance: 0.8974665817390262
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.412338381729569, tolerance: 0.9288010724096488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.700123346834516, tolerance: 0.9288010724096488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.240633929533942, tolerance: 0.9288010724096488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.934998025333698, tolerance: 0.9288010724096488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.6499920267297057, tolerance: 0.8974665817390262
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.334840690866258, tolerance: 0.8974665817390262
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.692035977367595, tolerance: 0.9288010724096488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.427566537625353, tolerance: 0.9288010724096488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.06378975194639, tolerance: 0.9288010724096488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.52873694584923, tolerance: 0.9288010724096488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.75577777977742, tolerance: 0.9288010724096488
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.587028115866815, tolerance: 0.90272993573477
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.9605788712069625, tolerance: 0.90272993573477
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.565963677496256, tolerance: 0.90272993573477
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.295427454376295, tolerance: 0.90272993573477
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.05032238621243, tolerance: 0.90272993573477
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.740253250231945, tolerance: 0.90272993573477
#   model = cd_fast.enet_coordinate_descent_gram(
# <ipython-input-6-fb50426e5489>:78: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4161699148946809, tolerance: 0.20214429290130265
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1668526759485758, tolerance: 0.20214429290130265
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3258676597799877, tolerance: 0.20214429290130265
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4647915160937828, tolerance: 0.2032435737431891
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.918280243150548, tolerance: 0.20214429290130265
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.9685816169630925, tolerance: 0.20214429290130265
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2584234854937222, tolerance: 0.2032435737431891
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.46977190394432, tolerance: 0.2032435737431891
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9031530663567082, tolerance: 0.20214429290130265
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9366536005270518, tolerance: 0.20214429290130265
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.3940449188137336, tolerance: 0.20214429290130265
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.299331400199208, tolerance: 0.20214429290130265
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46.323773868261924, tolerance: 0.8711403903145882
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.603343783310265, tolerance: 0.8825717023581049
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.95500282442936, tolerance: 0.8825717023581049
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 190.9191455434211, tolerance: 0.8711403903145882
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 373.19628338034545, tolerance: 0.8711403903145882
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115.37436697017347, tolerance: 0.8825717023581049
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 564.0315344383416, tolerance: 0.8711403903145882
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55.44965373065952, tolerance: 0.8711403903145882
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 340.16308111612125, tolerance: 0.8825717023581049
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 254.2861012304411, tolerance: 0.8711403903145882
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 587.9606625365668, tolerance: 0.8825717023581049
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 495.4754347386852, tolerance: 0.8711403903145882
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 736.1943909617185, tolerance: 0.8711403903145882
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 961.5531675766451, tolerance: 0.8711403903145882
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.81697142075427, tolerance: 0.8906366071335775
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.29196159079311, tolerance: 0.9066715105567419
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 197.07457495018753, tolerance: 0.9066715105567419
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 386.21846719657333, tolerance: 0.9066715105567419
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 584.2690062408647, tolerance: 0.9066715105567419
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.83832072007317, tolerance: 0.9066715105567419
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 260.06889055398005, tolerance: 0.9066715105567419
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 510.5446409616525, tolerance: 0.9066715105567419
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 760.8700157427711, tolerance: 0.9066715105567419
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 995.2853739666389, tolerance: 0.9066715105567419
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6190732542672777, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.341705514154455, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.744247466151137, tolerance: 0.8065544471337062
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.572431414219864, tolerance: 0.8065544471337062
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.614049819022512, tolerance: 0.8065544471337062
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81.65008806497463, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 280.62430702979054, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 507.96656415810503, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.187611800375635, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 731.0606906841813, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 114.11649730305544, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 276.1807822944338, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 456.1729018160595, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 636.5412805921378, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 938.6764450375426, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 809.5043346825923, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1127.8015868152552, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1298.6383824467293, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 971.8845451812031, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1122.7231715094158, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1262.1285898284882, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1452.5824707473903, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1591.3803127890742, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1716.779116735202, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1830.3900004162742, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1390.7027851620178, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1933.6448185054128, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 982.6492564796781, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2027.7935628455243, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1171.8903617097644, tolerance: 0.8034807360146572
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2113.9182488017645, tolerance: 0.7970539527311318
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.02898169209584, tolerance: 0.8410347688872688
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.770636829241994, tolerance: 0.9269319691902962
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.077856636808065, tolerance: 0.8915003323193512
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.3602357619856775, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.929092855114504, tolerance: 0.9269319691902962
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.218358791498758, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.151885099649007, tolerance: 0.9269319691902962
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.220300624871015, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.34569887315956, tolerance: 0.9269319691902962
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.409019896296741, tolerance: 0.9134283682261949
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.959922368259868, tolerance: 0.9134283682261949
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.691286727791521, tolerance: 0.9134283682261949
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.5869364491172746, tolerance: 0.8843771345170987
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.495619037266806, tolerance: 0.9134283682261949
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.054474563094118, tolerance: 0.8843771345170987
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.275271274635088, tolerance: 0.9134283682261949
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.811562788709125, tolerance: 0.8843771345170987
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.94130839907575, tolerance: 0.9134283682261949
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.744314693364686, tolerance: 0.8843771345170987
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.7484919721428, tolerance: 0.8843771345170987
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.728613827269328, tolerance: 0.8843771345170987
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.408922651260582, tolerance: 0.9269319691902962
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144.76481906405934, tolerance: 0.9269319691902962
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 384.70552512531594, tolerance: 0.9269319691902962
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 642.8289546233746, tolerance: 0.9269319691902962
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103.79608689953693, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 330.1796380703963, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 583.7618489415227, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 830.7008550382343, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1059.5775260966657, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124.07731939731184, tolerance: 0.8915003323193512
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1267.542868940137, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 351.57035572711084, tolerance: 0.8915003323193512
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50.97603591605548, tolerance: 0.9134283682261949
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1455.0652221380392, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1623.8166358340586, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 599.9369630545698, tolerance: 0.8915003323193512
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1775.7976454338377, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 839.9201476360922, tolerance: 0.8915003323193512
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1912.977949683922, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 253.94261685858874, tolerance: 0.9134283682261949
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1061.7482560942353, tolerance: 0.8915003323193512
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2037.159405748359, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 504.11237520668874, tolerance: 0.9134283682261949
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2149.935923067587, tolerance: 0.9191909552569171
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1263.1515351940006, tolerance: 0.8915003323193512
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1444.766941009123, tolerance: 0.8915003323193512
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1608.275145042875, tolerance: 0.8915003323193512
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1755.6259689925191, tolerance: 0.8915003323193512
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1888.720559824712, tolerance: 0.8915003323193512
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.073e+03, tolerance: 1.134e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.073e+03, tolerance: 1.134e+00
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-6-fb50426e5489>:78: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
N = 5000
i = 0
for t in ['constant','linear','quadratic','piecewise','piecewise_linear']:

    df = gen_data_hte(N, t)
    
    df['x2'] = df['x'].pow(2)
    df['x2_ln'] = np.log(1+df['x'])
    for p in range(9):
        df['x_'+str(p)] = ( np.round(df['x'],1)==np.round(p*0.1,1) ).astype(float)
        df['x_X'+str(p)] = df['x_'+str(p)]*df['x']
    full_feature_list = [ x for x in df.columns if 'x' in x]

    
    SGCT = st.hte.het_dml_approaches.SGCT(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, aux_dictionary)
    df['dml_SGCT_TE'] = SGCT[0]
    df['dml_SGCT_SE'] = SGCT[1]    
    df['dml_SGCT_P'] = SGCT[2]
    df['dml_SGCT_Y0'] = SGCT[3]        

    HR = st.hte.het_dml_approaches.HR(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, aux_dictionary)
    df['dml_HR_TE'] = HR[0]
    df['dml_HR_SE'] = HR[1]    
    df['dml_HR_P'] = HR[2]
    df['dml_HR_Y0'] = HR[3]

    dr_cvl = st.hte.other.DR(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, {'force_second_stage':'CVLasso'})
    df['DR_CVL_TE'] = dr_cvl[0]
    df['DR_CVL_SE'] = dr_cvl[1]   
    df['DR_CVL_P'] = dr_cvl[2]
    df['DR_CVL_Y0'] = dr_cvl[3]


    tree_grf = st.hte.trees.grf(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, {'n_estimators':1000})
    df['GRF_TE'] = tree_grf[0]
    df['GRF_SE'] = tree_grf[1]
    df['GRF_P'] = tree_grf[2]
    df['GRF_Y0'] = tree_grf[3]

    fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(20,10),sharex=True, sharey=True)

    ax[0].scatter(df['x'], df['dml_SGCT_TE'], label='SGCT', alpha = 0.15, color='green')
    ax[0].scatter(df['x'], df['dml_HR_TE'], label='HR', alpha = 0.15, color='coral')
    ax[0].scatter(df['x'], df['hte'], label='Truth', alpha = 0.25, color='royalblue')

    ax[0].legend(loc='upper left', fontsize=15)
    ax[0].grid()
    ax[0].set_ylabel('HTE', fontsize=15)
    ax[0].set_xlabel('x', fontsize=15)
    
    ax[1].scatter(df['x'], df['DR_CVL_TE'], label='DoublyRobust', alpha = 0.15, color='purple')
    ax[1].scatter(df['x'], df['GRF_TE'], label='GRF', alpha = 0.15, color='pink')
    ax[1].scatter(df['x'], df['hte'], label='Truth', alpha = 0.25, color='royalblue')
    
    ax[1].legend(loc='upper left', fontsize=15)
    ax[1].grid()
    ax[1].set_ylabel('HTE', fontsize=15)
    ax[1].set_xlabel('x', fontsize=15)
    fig.subplots_adjust(wspace=0.05, hspace=0)
    fig.suptitle('Performance when Functional Form is {0}'.format(i), fontsize=15) 
    fig.patch.set_facecolor('white')
    fig.show()
    i+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d59c4ab542d4> in <module>
#      13
#      14     ## 3. Run through each combination of models
# ---> 15     SGCT = hte.het_dml_approaches.SGCT(df,
#      16                     full_feature_list, 'y', 't',
#      17                     full_feature_list,
#
# NameError: name 'hte' is not defined
