# %% [markdown]
# # Heterogenous treatment effect models
# Julian Hsu
# 30 Aug 2021
#
# ### Table of Contents with Navigation Links
# * [Write ML Models](#Section1)
# * [Simulator Functions](#Section2)
# * [Many Simulations](#Section3)

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

import numpy as np
import os as os 
import scipy.stats 

from matplotlib import gridspec
import matplotlib.pyplot as plt
# %matplotlib inline  

import statsmodels.api as sm
from IPython.display import display    

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, LinearRegression, Lasso, LassoCV, Ridge
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.neural_network import MLPRegressor, MLPClassifier
from sklearn.metrics import mean_squared_error

import warnings

# %%
print(os.getcwd())
import stnomics as st
# Out:
# /Users/hsujulia/Documents/GitHub/statanomics/examples

# %%
def gen_data_hte(N, hte_type):
    '''
    Generate data with different types of HTE forms:
    '''
    
    df = pd.DataFrame()
    x = np.random.uniform(0,1, N)
    y = 10 + 2*(np.log(1+x)) + x**2 + np.random.normal(0,1,N)
    
    if hte_type=='constant':
        hte = 1
    elif hte_type=='linear':
        hte = 2*x
    elif hte_type=='quadratic':
        hte = 0.5*x**2
    elif hte_type=='piecewise':
        hte = np.zeros_like(x)
        hte[(x < 0.20)] = 1
        hte[(x >=0.20) & (x < 0.80) ] = 2
        hte[(x >=0.80) ] = 5
    elif hte_type=='log':
        hte = np.log(1+x*2)*1.5
    elif hte_type=='piecewise_linear':
        hte = np.zeros_like(x)
        hte[(x < 0.20)] = x[(x < 0.20)]*0.1
        hte[(x >=0.20) & (x < 0.80) ] = x[(x >=0.20) & (x < 0.80) ]*0.75
        hte[(x >=0.80) ] = x[(x >=0.80) ]*(-0.5)
    elif hte_type=='trig':
        hte = np.sin(1+x*10)*x
    else:
        print('Choose a hte type!')
        
    t = ( np.exp(x) / (1+np.exp(x)) > np.random.uniform(0,1,N)).astype(float)
    y  += t*hte
    return pd.DataFrame(data={'x':x, 't':t, 'y':y, 'hte': hte})

# %%
model_max_iter = 5000
## treatment prediction models
t_models = {}
t_models['LogitCV'] = LogisticRegressionCV(cv=5, random_state=27, n_jobs=-1)
t_models['logit'] = LogisticRegression(penalty='l2',solver='lbfgs', C=1, max_iter=model_max_iter, fit_intercept=True)
t_models['logit_L1_C2'] = LogisticRegression(penalty='l1',C=2, max_iter=model_max_iter, fit_intercept=True)
t_models['logit_L2_C5'] = LogisticRegression(penalty='l2',C=2, max_iter=model_max_iter, fit_intercept=True)
t_models['rf_md10'] = RandomForestClassifier(n_estimators=25,max_depth=10, min_samples_split=200,n_jobs=-1)
t_models['rf_md3'] = RandomForestClassifier(n_estimators=25,max_depth=3, min_samples_split=200,n_jobs=-1)
t_models['nn'] = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(3, 2), random_state=1,max_iter=model_max_iter)
## outcome prediction models
y_models = {}
y_models['LassoCV'] = LassoCV(cv=5, n_jobs=-1,random_state=27)
y_models['ols'] = LinearRegression()
y_models['lasso_a2'] = Lasso(alpha=2,max_iter=model_max_iter)
y_models['ridge_a2'] = Ridge(alpha=2,max_iter=model_max_iter)
y_models['rf_md10'] = RandomForestRegressor(n_estimators=25,max_depth=10, min_samples_split=200,n_jobs=-1)
y_models['rf_md3'] = RandomForestRegressor(n_estimators=25,max_depth=3, min_samples_split=200,n_jobs=-1)
y_models['nn'] = MLPRegressor(alpha=1e-5, hidden_layer_sizes=(3, 2), random_state=1, max_iter=model_max_iter)

# %%
aux_dictionary = {'force_second_stage':'CVLasso'}
n_data_splits = 5
lasso_max_iter = 5000
lasso_alpha = 5

# from sklearn.utils.testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# %%
N = 5000
i = 0
for t in ['constant','linear','quadratic','piecewise','piecewise_linear']:

    df = gen_data_hte(N, t)
    
    df['x2'] = df['x'].pow(2)
    df['x2_ln'] = np.log(1+df['x'])    
#     for p in range(9):
#         df['x_'+str(p)] = ( np.round(df['x'],1)==np.round(p*0.1,1) ).astype(float)
#         df['x_X'+str(p)] = df['x_'+str(p)]*df['x']
    full_feature_list = [ x for x in df.columns if 'x' in x]

    ## 3. Run through each combination of models
    SGCT = st.hte.het_dml_approaches.SGCT(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, aux_dictionary)
    df['dml_SGCT_TE'] = SGCT[0]
    df['dml_SGCT_SE'] = SGCT[1]    
    df['dml_SGCT_P'] = SGCT[2]
    df['dml_SGCT_Y0'] = SGCT[3]        

    HR = st.hte.het_dml_approaches.HR(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, aux_dictionary)
    df['dml_HR_TE'] = HR[0]
    df['dml_HR_SE'] = HR[1]    
    df['dml_HR_P'] = HR[2]
    df['dml_HR_Y0'] = HR[3]

    dr_cvl = st.hte.other.DR(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, {'force_second_stage':'CVLasso'})
    df['DR_CVL_TE'] = dr_cvl[0]
    df['DR_CVL_SE'] = dr_cvl[1]   
    df['DR_CVL_P'] = dr_cvl[2]
    df['DR_CVL_Y0'] = dr_cvl[3]


    tree_grf = st.hte.trees.grf(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, {'n_estimators':1000})
    df['GRF_TE'] = tree_grf[0]
    df['GRF_SE'] = tree_grf[1]
    df['GRF_P'] = tree_grf[2]
    df['GRF_Y0'] = tree_grf[3]

    fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(20,10),sharex=True, sharey=True)

    ax[0].scatter(df['x'], df['dml_SGCT_TE'], label='SGCT', alpha = 0.15, color='green')
    ax[0].scatter(df['x'], df['dml_HR_TE'], label='HR', alpha = 0.15, color='coral')
    ax[0].scatter(df['x'], df['hte'], label='Truth', alpha = 0.50, color='royalblue')

    ax[0].legend(loc='upper left', fontsize=20)
    ax[0].grid()
    ax[0].set_ylabel('HTE', fontsize=20)
    ax[0].set_xlabel('x', fontsize=20)
    ax[0].tick_params(axis='both', which='major', labelsize=20)
    
    ax[1].scatter(df['x'], df['DR_CVL_TE'], label='Proxy', alpha = 0.15, color='purple')
    ax[1].scatter(df['x'], df['GRF_TE'], label='GRF', alpha = 0.25, color='pink')
    ax[1].scatter(df['x'], df['hte'], label='Truth', alpha = 0.50, color='royalblue')
    
    ax[1].legend(loc='upper left', fontsize=20)
    ax[1].grid()
    ax[1].set_ylabel('HTE', fontsize=20)
    ax[1].set_xlabel('x', fontsize=20)
    ax[1].tick_params(axis='both', which='major', labelsize=20)
    fig.subplots_adjust(wspace=0.05, hspace=0)
    fig.suptitle('Performance when Functional Form is {0}'.format(i), fontsize=20) 
    fig.patch.set_facecolor('white')
    fig.show()
    i+=1
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.48963574325899, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 174.75344461171062, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 361.97472567517434, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 135.43613805802852, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 371.99864858240016, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57.24605307708134, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84.17160962808248, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 264.7010529727313, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 628.3805483329606, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 303.3132617777701, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 875.4990778238171, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1103.6946407018768, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 516.7319634477626, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1310.7926225036344, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 555.8899105448791, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 768.3456285954662, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1003.8933537914791, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 804.1678305601308, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1035.2201445690744, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1497.5149677242825, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1218.84770939408, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1245.583100733179, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1413.0156776679332, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1435.471811582188, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1606.4590935170445, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1665.6176239685396, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1587.8340078658134, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1760.5135434528324, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82.2101379497617, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1817.1161228178785, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1745.2501660989346, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1899.6022181220555, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1953.9683704442555, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1887.2574434775283, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2025.536452879077, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2015.710850989522, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2132.265805386709, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 243.55211456964116, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2238.3700792650534, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115.17250442340082, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2139.9238995286305, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2077.955548842932, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2335.2776653449937, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 353.0486789760307, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2244.1662930131824, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 617.5316418041903, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2339.475640353632, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2424.070305657896, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2190.649550366161, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 431.8149687628629, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 874.6206264047523, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2426.8964499725844, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2505.6803042417455, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2580.911917792221, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2293.417290273088, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 623.7983425499697, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84.04843529776554, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2507.3285082232437, tolerance: 0.8961716746910309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2650.4603429245763, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2387.4394108137753, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1112.8284565743634, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2473.733203618854, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2714.9280981173297, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 297.7410476125651, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2553.1752845196556, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 543.2168296893951, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2626.5222194622966, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2774.8389516003454, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1329.3136469210303, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 784.3229445469005, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2694.428547257597, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1008.6636079463169, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1524.5925804756353, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2757.46219383028, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1700.4023910864425, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2830.649669770036, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2816.117509771835, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1212.9236987469158, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2870.826233785714, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2882.7598914894397, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1397.3235444320367, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2931.5204186068327, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2921.9666940269562, tolerance: 0.9069867363418309
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1563.389631977716, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1858.8127761758328, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2977.2401806181533, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1713.0293327626105, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3020.192094911755, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1848.1481841770678, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2001.860211250451, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1970.5011614744153, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2131.4080701007874, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3060.61800838664, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2081.6463098965596, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3098.732876891691, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2249.1055316114425, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3134.72830688493, tolerance: 0.9034692350010175
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2182.942511448777, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2356.3888564434806, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2275.5650619657545, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2454.4994968286564, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2360.5271126197767, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2544.507466604495, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2438.701659015805, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2627.334850478532, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2510.841871728714, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2703.7773591619175, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2774.5232395273392, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2577.599005331682, tolerance: 0.8733363606246815
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2840.169485262407, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2901.235568932691, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2958.174997993018, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3011.3850152441423, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3061.21473829189, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3107.9719955915066, tolerance: 0.9364827059833978
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.9816025119289407, tolerance: 0.8340016997023139
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.893292293189916, tolerance: 0.8340016997023139
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9793436353738798, tolerance: 0.8648602697074481
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.977141116185521, tolerance: 0.8340016997023139
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.102990220408174, tolerance: 0.8648602697074481
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0805749625451426, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100.6880416659069, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 269.7669885701125, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.543990450223646, tolerance: 0.8648602697074481
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.139505241939332, tolerance: 0.8340016997023139
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.200668280607715, tolerance: 0.8648602697074481
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 462.5125880013011, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.979048694876838, tolerance: 0.8648602697074481
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 657.592070671034, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 845.5085910625876, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.792193609400783, tolerance: 0.8648602697074481
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 271.0086164893519, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 518.4867949825812, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 764.7366453458817, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 995.1826785473131, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1205.6186208323024, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1395.904813396664, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1567.4374068455163, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1722.094731419846, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1861.797277901936, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1988.3326196521625, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2103.2968048003813, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2208.086519458472, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2303.9122584859033, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2391.818894545326, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2472.7075343910224, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.478419062144894, tolerance: 0.8606253033370839
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152.02461467641115, tolerance: 0.8606253033370839
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 384.20391360969916, tolerance: 0.8606253033370839
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 631.5625048192833, tolerance: 0.8606253033370839
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2547.35604506353, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2616.437292390732, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 868.9476802922863, tolerance: 0.8606253033370839
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125.03678316566675, tolerance: 0.8829920874558616
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2680.534890968011, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1088.007827641285, tolerance: 0.8606253033370839
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.043936334784121, tolerance: 0.8340016997023139
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2740.1566034237885, tolerance: 0.8701922175671917
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.91825049252384, tolerance: 0.8864381468450128
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 129.2932531256629, tolerance: 0.8927813950210428
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 358.99969613394205, tolerance: 0.8927813950210428
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.442e+03, tolerance: 1.124e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.442e+03, tolerance: 1.124e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.2457031918784196, tolerance: 0.8720500842096128
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7244119008173584, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.377117715699569, tolerance: 0.8707255221587316
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.5722930906486, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.43802492877694, tolerance: 0.8720500842096128
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.62841525775093, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.057998707075967, tolerance: 0.8707255221587316
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.86490969364786, tolerance: 0.8720500842096128
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.927428072313887, tolerance: 0.8707255221587316
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.790210737815869, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.891502658379977, tolerance: 0.8707255221587316
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.42117629036511, tolerance: 0.8720500842096128
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.86433220501749, tolerance: 0.8707255221587316
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20.7644971561931, tolerance: 0.8707255221587316
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.17577921364591, tolerance: 0.8720500842096128
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 191.44384988256388, tolerance: 0.8707255221587316
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 201.46396154010745, tolerance: 0.8720500842096128
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.7318464723448415, tolerance: 0.8740006129343387
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 438.4923628017159, tolerance: 0.8720500842096128
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 681.6757540548479, tolerance: 0.8720500842096128
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.166334098830703, tolerance: 0.8740006129343387
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.800018043480122, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.835338342725663, tolerance: 0.8740006129343387
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193.02325010938694, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 424.0879510307168, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.641842826278662, tolerance: 0.8740006129343387
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 661.7443683693391, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 886.8157969621898, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.49656772576509, tolerance: 0.8740006129343387
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1093.2710797047976, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.317195266197814, tolerance: 0.8740006129343387
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1280.208916848721, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.02769945046202, tolerance: 0.8740006129343387
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1448.6986178264178, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49.557762014401305, tolerance: 0.8740006129343387
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1600.4777199131245, tolerance: 0.8526989215385957
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9774172155430279, tolerance: 0.8698824884830177
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.011934086280235, tolerance: 0.8698824884830177
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.296335108860148, tolerance: 0.8698824884830177
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.730816168038473, tolerance: 0.8698824884830177
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.223579048544707, tolerance: 0.8698824884830177
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.690052200890932, tolerance: 0.8698824884830177
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.052209790917914, tolerance: 0.8698824884830177
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46.23797350897894, tolerance: 0.8698824884830177
#   model = cd_fast.enet_coordinate_descent_gram(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.963e+03, tolerance: 1.085e+00
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.963e+03, tolerance: 1.085e+00
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-7-88371d41d593>:80: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
N = 5000
i = 0
# for t in ['constant','linear','quadratic','piecewise','piecewise_linear']:
for t in ['linear','piecewise_linear']:
    df = gen_data_hte(N, t)
    
#     df['x2'] = df['x'].pow(2)
#     df['x2_ln'] = np.log(1+df['x'])
#     for p in range(9):
#         df['x_'+str(p)] = ( np.round(df['x'],1)==np.round(p*0.1,1) ).astype(float)
#         df['x_X'+str(p)] = df['x_'+str(p)]*df['x']
    full_feature_list = [ x for x in df.columns if 'x' in x]

    
    SGCT = st.hte.het_dml_approaches.SGCT(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, aux_dictionary)
    df['dml_SGCT_TE'] = SGCT[0]
    df['dml_SGCT_SE'] = SGCT[1]    
    df['dml_SGCT_P'] = SGCT[2]
    df['dml_SGCT_Y0'] = SGCT[3]        

    HR = st.hte.het_dml_approaches.HR(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, aux_dictionary)
    df['dml_HR_TE'] = HR[0]
    df['dml_HR_SE'] = HR[1]    
    df['dml_HR_P'] = HR[2]
    df['dml_HR_Y0'] = HR[3]

    dr_cvl = st.hte.other.DR(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, {'force_second_stage':'CVLasso'})
    df['DR_CVL_TE'] = dr_cvl[0]
    df['DR_CVL_SE'] = dr_cvl[1]   
    df['DR_CVL_P'] = dr_cvl[2]
    df['DR_CVL_Y0'] = dr_cvl[3]


    tree_grf = st.hte.trees.grf(df, 
                    full_feature_list, 'y', 't',
                    full_feature_list,
                    y_models['ols'], t_models['logit'],
                   n_data_splits, {'n_estimators':1000})
    df['GRF_TE'] = tree_grf[0]
    df['GRF_SE'] = tree_grf[1]
    df['GRF_P'] = tree_grf[2]
    df['GRF_Y0'] = tree_grf[3]

    fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10),sharex=True, sharey=True)


#     ax[0].scatter(df['x'], df['dml_HR_TE'], label='HR', alpha = 0.15, color='coral')
#     ax[0].scatter(df['x'], df['hte'], label='Truth', alpha = 0.25, color='royalblue')

#     ax[0].legend(loc='upper left', fontsize=15)
#     ax[0].grid()
#     ax[0].set_ylabel('HTE', fontsize=15)
#     ax[0].set_xlabel('x', fontsize=15)

    ax.scatter(df['x'], df['dml_SGCT_TE'], label='SGCT', alpha = 0.50, color='green')    
    ax.scatter(df['x'], df['DR_CVL_TE'], label='Proxy', alpha = 0.50, color='purple')
    ax.scatter(df['x'], df['GRF_TE'], label='GRF', alpha = 0.50, color='coral')
    ax.scatter(df['x'], df['hte'], label='Truth', alpha = 0.50, color='royalblue')    
    ax.legend(loc='upper left', fontsize=20, markerscale=3)
    ax.grid()
    ax.set_ylabel('HTE', fontsize=20)
    ax.set_xlabel('x', fontsize=20)
    ax.tick_params(axis='both', which='major', labelsize=20)
    fig.subplots_adjust(wspace=0.05, hspace=0)
    fig.suptitle('Performance when Functional Form is {0}'.format(t), fontsize=25) 
    fig.patch.set_facecolor('white')
    fig.show()
    
    i+=1
